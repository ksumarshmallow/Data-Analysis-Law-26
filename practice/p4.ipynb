# %% [markdown]
# # **Практика 4. Частотные таблицы. Визуализация.**

# %% [markdown]
# [SmartLMS](https://edu.hse.ru/mod/quiz/view.php?id=1918957)

# %% [markdown]
# ам предоставлены данные по кибербезопаности, где каждое наблюдение, это одна кибератака.
#
# Датасет содержит следующие признаки:
#
# - `Country`: страна
# - `Year`: год
# - `Attack Type`: тип кибер атаки
# - `Target Industry`: какая отрасль подверглась кибератаке
# - `Financial Loss (in Million $)`: размер финансовых издержеек от кибератаки
# - `Number of Affected Users`: количество пользователей, которые пострадали
# - `Attack Source`: кто осуществлял кибератаку
# - `Security Vulnerability Type`: какая уязвимость системы
# - `Defense Mechanism Used`: инструмент с помощью которого смогли восстановить работу системы
# - `Incident Resolution Time (in Hours)`: количество часов, которое понадобилось для восстановления работы системы

# %%
import pandas as pd
df = pd.read_csv('data/сybersecurity.csv')
df.head(2)
# Out:
#   Country  Year Attack Type Target Industry  Financial Loss (in Million $)  \
# 0   China  2019    Phishing       Education                          80.53
# 1   China  2019  Ransomware          Retail                          62.19
#
#    Number of Affected Users Attack Source Security Vulnerability Type  \
# 0                    773169  Hacker Group          Unpatched Software
# 1                    295961  Hacker Group          Unpatched Software
#
#   Defense Mechanism Used  Incident Resolution Time (in Hours)
# 0                    VPN                                   63
# 1               Firewall                                   71

# %% [markdown]
# ## **Задание 1**

# %% [markdown]
# ### 1.1
# Укажите, шкалу измерения признака `Number of Affected Users`:
# - количественный непрерывный
# - количественный дискретный
# - категориальный номинальный
# - категориальный бинарный
# - категориальный порядковый

# %% [markdown]
# ### 1.2
# Укажите какой из графиков показывает распределение признака `Number of Affected Users`

# %% [markdown]
# ![](data:image/png;base64,...)

# %% [markdown]
# ---

# %% [markdown]
# ## **Задание 2**

# %% [markdown]
# ### 2.1
# Создайте новый признак `Financial Loss per User`, который будет показывать финансовые потери в рассчете на одного пользователя (`Financial Loss (in Million $`)/`Number of Affected Users`). Укажите тип уязвимости (`Security Vulnerability Type`) для атаки с наименьшими значением `Financial Loss per User`, среди атак на сферу банкинга (**Banking**; `Target Industry`), осуществленных с помощью метода **Man-in-the-Middle** (`Attack Type`).

# %% [markdown]
# ### 2.2
# Укажите шкалу измерения признака `Financial Loss per User`:
# - количественный непрерывный
# - количественный дискретный
# - категориальный номинальный
# - категориальный бинарный
# - категориальный порядковый

# %% [markdown]
# ### 2.3
# Укажите какой из графиков показывает распределение признака `Financial Loss per User`.

# %% [markdown]
# ![](data:image/png;base64,...)

# %% [markdown]
# ---

# %% [markdown]
# ## **Задание 3**
# Соотнесите гистограмму и ящик с усами.

# %% [markdown]
# ![](data:image/png;base64,...)

# %% [markdown]
# ---

# %% [markdown]
# ## **Задание 4**
# Укажите какой из графиков показывает зависимость признаков `Financial Loss per User` и `Incident Resolution Time (in Hours)`.

# %% [markdown]
# ![](data:image/png;base64,...)

# %% [markdown]
# ---

# %% [markdown]
# ## **Задание 5**

# %% [markdown]
# ### 5.1
# Укажите в каком году (`Year`) было было зафиксировано 318 кибератак.

# %% [markdown]
# ### 5.2
# Укажите какой из графиков показывает динамику количества кибератак по годам (`Year`).

# %% [markdown]
# ![](data:image/png;base64,...)

# %% [markdown]
# ---

# %% [markdown]
# ## **Задание 6**

# %% [markdown]
# ### 6.1
# Создайте новый признак `FL_coded` на основе признака `Financial Loss (in Million $)`. Логика нового признака:
# - если значение `Financial Loss (in Million $)` больше 75 миллионов долларов, вернуть **1**
# - иначе вернуть **0**.
#
# Укажите долю кибератак, которые относятся к категории **0** (`FL_coded`). Ответ округлите до двух знаков.

# %% [markdown]
# ### 6.2
# Укажите шкалу измерения признака `FL_coded`:
# - количественный непрерывный
# - количественный дискретный
# - категориальный номинальный
# - категориальный бинарный
# - категориальный порядковый

# %% [markdown]
# ### 6.3
# Укажите какой из графиков показывает распределение признака `FL_coded`.

# %% [markdown]
# ![](data:image/png;base64,...)

# %% [markdown]
# ---

# %% [markdown]
# ## **Задание 7**

# %% [markdown]
# ### 7.1
# Укажите шкалу измерения признака `Attack Source`:
# - количественный непрерывный
# - количественный дискретный
# - категориальный номинальный
# - категориальный бинарный
# - категориальный порядковый

# %% [markdown]
# ### 7.2
# Найдите, кто чаще других совершает совершает хакерские атаки (`Attack Source`). Укажите сколько кибератак совершила эта группа.

# %% [markdown]
# ### 7.3
# Укажите какой из графиков показывает распределение признака `Attack Source`.

# %% [markdown]
# ![](data:image/png;base64,...)

# %% [markdown]
# ---

# %% [markdown]
# ## **Задание 8**
# Укажите какой из графиков показывает динамику количества кибератак в России (**Russia**; `Country`).

# %% [markdown]
# ![](data:image/png;base64,...)

# %% [markdown]
# ---

# %% [markdown]
# ## **Задание 9**

# %% [markdown]
# ### 9.1
# Укажите в какой отрасли (`Target Industry`), для борьбы с кибератаками, чаще всего используют фаервол (**Firewall**; `Defense Mechanism Used`).

# %% [markdown]
# ### 9.2
# Укажите какой из графиков показывает распределение кибератак по отраслям (`Target Industry`), для тех случаев, когда инструментом восстановления был фаервол (**Firewall**; `Defense Mechanism Used`).

# %% [markdown]
# ![](data:image/png;base64,...)
