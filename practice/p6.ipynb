# %% [markdown]
# # **Практика 6. Описательные статистики. Пропуски и выбросы.**

# %% [markdown]
# [SmartLMS](https://edu.hse.ru/mod/quiz/view.php?id=1918960)

# %% [markdown]
# Вам предоставлен датасет по судебной статистике в России.
#
# - `year`	-  год
# - `type`	-  правовые показатели
# - `cases`	 - количество рассмотренных дел
# - `approved`	 - количество удовлетворенных дел
# - `rate_approved` - 	 доля удовлетворенных дел
# - `refused`	 - количество отказов
# - `rate_refused` - 	 доля отказов
# - `dismissed`	-  количество прекращенных дел
# - `court_order`	-  количество судебных приказов
# - `rate_court_order`	-  доля судебных приказов
# - `penalties`	-  общая сумма взысканий (тыс. рублей)
# - `avg_penalties`	-  средняя сумма взысканий (тыс. рублей)
# - `legal_proceedings`	-  судопроизводство
# - `category` - 	 категория правового показателя

# %%
import pandas as pd

df = pd.read_csv(
    "https://raw.githubusercontent.com/ksumarshmallow/Data-Analysis-Law-26/refs/heads/main/practice/data/court_data.csv"
)
df.head(2)
# Out:
#    year                                         type    cases  approved  \
# 0  2016  О расторжении брака супругов, имеющих детей  80875.0   80728.0
# 1  2017  О расторжении брака супругов, имеющих детей  78767.0   78627.0
#
#    rate_approved  refused  rate_refused  dismissed  court_order  \
# 0       0.998182    147.0      0.001818    11510.0        103.0
# 1       0.998223    140.0      0.001777    11045.0          0.0
#
#    rate_court_order  penalties  avg_penalties legal_proceedings  category
# 0          0.001274    41586.0            1.0       Гражданское  Семейные
# 1          0.000000    48783.0            1.0       Гражданское  Семейные

# %% [markdown]
# # **Блок 1. Описательные статистики**

# %% [markdown]
# ## **Задание 1**
# Создайте сводную таблицу: по строкам - тип судопроизводства (`legal_proceedings`), а по стоблцам - среднее, медиана и стандартное отклонение доли отказов (`rate_refused`).

# %% [markdown]
# По созданной таблице отметьте верные утверждения:
# - Вариативность доли отказов выше в административном судопроизводстве
# - В гражданском судопроизводстве есть правовые показатели с экстремально высоким значением отказов
# - В административном судопроизводстве есть правовые показатели с экстремально низким значением отказов
# - В среднем, доля отказов в гражданском судопроизводстве выше, чем в административном
# - Для половины правовых показателей в гражданском судопроизводстве доля отказов превышает 0.19
# - В данных точно есть показатель административного судопроизводства с долей отказов 0.4

# %% [markdown]
# ---

# %% [markdown]
# ## **Задание 2**
# Опишите данные с которыми мы работаем. Ответы, отмеченные *, округлите до двух знаков. Текстовые ответы вводите также как они записаны в данных.

# %% [markdown]
# - В данных представлена судебная статистика с `???` по `???` год (`year`)
# - Правовые показатели (`type`) разделены по двум типам судопроизводства (`legal_proceedings`): `???` и `???`
# - Данные разделены на `???`  категорий (`category`). При этом наиболее распространенная категория (`category`) - это  `???` споры (`???`
#  судопроизводство (`legal_proceedings`))
#
# **Информация по 2023 году**
# - Было всего рассмотрено `???`  дел (`cases`). Из них, в среднем судом одобрено (`rate_approved`) `???`% \*
# - `???`  (`type`) характеризуются наибольшей суммой взысканий (`penalties`) и составляют `???` тыс. рублей. Но при этом, по *половине* правовых показателей (`type`), общий размер денежных взысканий (`penalties`) не превысил `???`  тыс. рублей.

# %% [markdown]
# ---

# %% [markdown]
# ## **Задание 3**
# Определите, для какой категории показателей (`category`), диапазон в котором лежит 50% центральных данных признака `rate_approved` наибольший.

# %% [markdown]
# ---

# %% [markdown]
# ## **Задание 4**
# Создайте в данных новый признак `legal_proceedings_coded`. Кодировку проведите следущим образом: если `legal_proceedings` - это **Гражданское судопроизводство**, то **1**, а если **Административное**, то **0**. В качестве ответа укажите меру центральной тенденции, которая будет показывать долю 1 по признаку `legal_proceedings_coded`. Ответ округлите до двух знаков.

# %% [markdown]
# ---

# %% [markdown]
# ## **Задание 5**
# Создайте новый признак `refused_coded` на основе признака `refused`. Кодировку проведите следующим образом: если доля отказов меньше чем первый квартиль - 1, меньше чем второй квартиль - 2, меньше чем третий квартиль - 3, во всех остальных случаях - 4. В ответ укажите значение меры центральной тенденции, которую можно интерпретировать для признака `refused_coded`.

# %% [markdown]
# ---

# %% [markdown]
# ## **Задание 6**
# Для категории (`category`), которая встречается в данных чаще всего, укажите правовой показатель (`type`), по котором общее количество судебных приказов(`court_order`) наибольшее.

# %% [markdown]
# ---

# %% [markdown]
# # **Блок 2. Пропуски и выбросы**

# %% [markdown]
# ## **Задание 7**
# Укажите в каких признаках есть пропуски

# %% [markdown]
# - `cases`
# - `refused`
# - `dismissed`
# - `penalties`
# - `category`

# %% [markdown]
# ---

# %% [markdown]
# ## **Задание 8**
# В признаке с 142 пропусками замените пропуски на медиану. В ответ впишите произведение средних по этому признаку до и после замены. Ответ округлите до двух знаков.

# %% [markdown]
# ---

# %% [markdown]
# ## **Задание 9**
# В признаке с 237 пропусками, замените пропуски на подходящую меру центральной тенденции. В ответ укажите долю самого популярного значения по этому признаку после замены. Ответ округлите до двух знаков.

# %% [markdown]
# ---

# %% [markdown]
# ## **Задание 10**
# Будем считать, что выбросами считаются наблюдения, которые отличаются от среднего арифметического на 3 стандартных отклонения и более. Определите, сколько показателей не считаются выбросами по признаку `dismissed`.

# %% [markdown]
# ---

# %% [markdown]
# ## **Задание 11**
# Был построен ящик с усами доли отказов (`rate_refused`) в гражданском судопроизводстве (`legal_proceedings`). Подпишите все точки на нем. Ответ округлите до двух знаков.

# %% [markdown]
# ![](data:image/png;base64,...)

# %% [markdown]
# ---

# %% [markdown]
# ## **Задание 12**
# На основании прошлого задания ответьте верные утверждения.

# %% [markdown]
# - В гражданском судопроизводстве по половине правовых показателей доля отказов меньше 0.19
# - В гражданском судопроизводстве средняя доля отказов меньше 0.19
# - В гражданском судопроизводстве для 25% правовых показателей доля отказов меньше 0.34
# - В гражданском судопроизводстве для 75% правовых показателей доля отказов больше 0.10
# - В гражданском судопроизводстве, любой правовой показатель с долей отказов больше 0.34, будет считаться выбросом.

# %% [markdown]
# ---

# %% [markdown]
# ## **Задание 13**

# %% [markdown]
# Определите сколько правовых показателей в гражданском судопроизводстве (`legal_proceedings`) считаются выбросами по доле отказов (`rate_refused`). Выбросы найдите с помощью метода 1.5 IQR.

# %% [markdown]
# ---
